# %% [markdown]
# # 1.5 layer rotating Shallow Water Equations (with rigid lid) (Reduced gravity setup)
#
# In this code we will solve the 1.5 layer shallow water equations, which
# These equations can be written in vector form as:
#
# $$
# \frac{\partial \mathbf{u}}{\partial t} + \mathbf{u}\cdot \nabla \mathbf{u} + \mathbf{f} \times \mathbf{u} = - g' \nabla h
# $$
#
# $$
# \frac{\partial h}{\partial t} + \nabla \cdot (\mathbf{u} h) = 0
# $$
#
# $$
# h = H + \eta_1
# $$
#
# where $\mathbf{u} = (u,v)$ is the velocity in th x-y plane and $h$ is the thickness of the upper (or dynamic) layer. $h$ may be decomposed into the mean thickness of the dynamic layer ($H$) and the variations of the interface between the dynamic and stagnant layer ($\eta_1$).  $g'$ is the reduced gravitational acceleration, and $\mathbf{f} = f_o \mathbf{k}$ is the Coriollis frequency (here we are considering the f-plane).
#
# > For more context see chapter 3 in the Vallis book.

# %%
import numpy as np
import dedalus.public as d3
import logging
logger = logging.getLogger(__name__)

# %%
# Parameters
Lx, Ly = 3000e3, 3000e3
Nx, Ny = 128, 128

delx = Lx/Nx

gprime = 9.81 * 5/1000 # made it reduced gravity
fo = 1e-4
H = 300

dealias = 3/2
stop_sim_time = 50 * 24 * 60 * 60 # Notice that thsi is different from other simulations 
timestepper = d3.RK222
#max_timestep = 30*60. # Use this as max time step if you want to have output frequency be close to the 1 layer simulations. 
max_timestep = delx / np.sqrt(gprime*H) #(we take shorter time step than what wave speed allows, for ensuring that simulation can be tracked)
dtype = np.float64

# %%
# Bases
coords = d3.CartesianCoordinates('x', 'y')
dist = d3.Distributor(coords, dtype=dtype)
xbasis = d3.RealFourier(coords['x'], size=Nx, bounds=(-Lx, Lx), dealias=dealias)
ybasis = d3.RealFourier(coords['y'], size=Ny, bounds=(-Ly, Ly), dealias=dealias)

# Fields
#e = dist.Field(name='e', bases=(xbasis,ybasis)) # surface eta
h = dist.Field(name='h', bases=(xbasis,ybasis)) # surface eta
u = dist.VectorField(coords, name='u', bases=(xbasis,ybasis))
#w = dist.Field(name='w', bases=(xbasis,zbasis))
#tau_p = dist.Field(name='tau_p')

x, y = dist.local_grids(xbasis, ybasis)
ex, ey = coords.unit_vector_fields(dist)

# %%
zcross = lambda A: d3.skew(A)

# %%
problem = d3.IVP([h, u], namespace=locals())

# %%
problem.add_equation("dt(u) + gprime*grad(h) + fo*zcross(u) = - u@grad(u)")
problem.add_equation("dt(h) = - div(u * h)")
# Out:
# {'eqn': Add(dt(<Field 5184125120>), Mul(-1, Mul(-1, Div(Mul(<Field 5184531152>, <Field 5184125120>))))),
#  'LHS': dt(<Field 5184125120>),
#  'RHS': Mul(-1, Div(Mul(<Field 5184531152>, <Field 5184125120>))),
#  'condition': 'True',
#  'tensorsig': (),
#  'dtype': dtype('float64'),
#  'valid_modes': array([[ True, False,  True, ...,  True,  True,  True],
#         [False, False, False, ..., False, False, False],
#         [ True, False,  True, ...,  True,  True,  True],
#         ...,
#         [ True, False,  True, ...,  True,  True,  True],
#         [ True, False,  True, ...,  True,  True,  True],
#         [ True, False,  True, ...,  True,  True,  True]], shape=(128, 128)),
#  'M': <Field 5184125120>,
#  'L': 0,
#  'F': Mul(-1, Div(Mul(<Field 5184531152>, <Field 5184125120>))),
#  'domain': <dedalus.core.domain.Domain at 0x134ff7a10>,
#  'matrix_dependence': array([False, False]),
#  'matrix_coupling': array([False, False])}

# %%
from dedalus.extras.plot_tools import plot_bot_2d

sigma1 = 500e3
#sigma2 = 300e3

gauss_bump1 = np.exp(-((x)**2 + (y)**2) / (2 * sigma1**2))
#gauss_bump2 = np.exp(-((x-500e3)**2 + (y)**2) / (2 * sigma2**2))

A = 1
h['g'] = A * gauss_bump1/ np.max(gauss_bump1) + H

#A*gauss_bump1/ np.max(gauss_bump1) - A*gauss_bump2/ np.max(gauss_bump2) + H

# Plot grid values
plot_bot_2d(h,title="f['g']");

# %%
# Solver
solver = problem.build_solver(timestepper)
solver.stop_sim_time = stop_sim_time
# Out:
# 2025-03-31 15:59:36,093 subsystems 0/1 INFO :: Building subproblem matrices 1/64 (~2%) Elapsed: 0s, Remaining: 1s, Rate: 7.8e+01/s
# 2025-03-31 15:59:36,138 subsystems 0/1 INFO :: Building subproblem matrices 7/64 (~11%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+02/s
# 2025-03-31 15:59:36,194 subsystems 0/1 INFO :: Building subproblem matrices 14/64 (~22%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+02/s
# 2025-03-31 15:59:36,246 subsystems 0/1 INFO :: Building subproblem matrices 21/64 (~33%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+02/s
# 2025-03-31 15:59:36,299 subsystems 0/1 INFO :: Building subproblem matrices 28/64 (~44%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+02/s
# 2025-03-31 15:59:36,352 subsystems 0/1 INFO :: Building subproblem matrices 35/64 (~55%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+02/s
# 2025-03-31 15:59:36,404 subsystems 0/1 INFO :: Building subproblem matrices 42/64 (~66%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+02/s
# 2025-03-31 15:59:36,456 subsystems 0/1 INFO :: Building subproblem matrices 49/64 (~77%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+02/s
# 2025-03-31 15:59:36,508 subsystems 0/1 INFO :: Building subproblem matrices 56/64 (~88%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+02/s
# 2025-03-31 15:59:36,560 subsystems 0/1 INFO :: Building subproblem matrices 63/64 (~98%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+02/s
# 2025-03-31 15:59:36,569 subsystems 0/1 INFO :: Building subproblem matrices 64/64 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+02/s

# %%
# Analysis
sim_dt =  30 *60
max_writes = stop_sim_time/sim_dt + 10
data_fname = 'snapshots_RSWE_reduced'
snapshots = solver.evaluator.add_file_handler(data_fname, 
                                              sim_dt=sim_dt, 
                                              max_writes=max_writes)
snapshots.add_task(u, name='uvec')
snapshots.add_task(h, name='height')
snapshots.add_task(-d3.div(d3.skew(u)), name='vorticity')
snapshots.add_task(d3.div(u), name='divergence')

#snapshots.add_task(-d3.div(d3.skew(u)), name='vorticity')

# %%
# CFL (adapt time step as needed)
CFL = d3.CFL(solver, initial_dt=max_timestep, cadence=10, 
             safety=0.5, threshold=0.05,
             max_change=1.5, min_change=0.5, max_dt=max_timestep)
CFL.add_velocity(u)

# %%
# Main loop
startup_iter = 10
try:
    logger.info('Starting main loop')
    while solver.proceed:
        timestep = CFL.compute_timestep()
        solver.step(timestep)
        if (solver.iteration-1) % 10 == 0:
            
            logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
except:
    logger.error('Exception raised, triggering end of main loop.')
    raise
finally:
    solver.log_stats()
# Out:
# 2025-03-31 15:59:36,726 __main__ 0/1 INFO :: Starting main loop
# 2025-03-31 15:59:37,649 __main__ 0/1 INFO :: Iteration=1, Time=6.109858e+03, dt=6.109858e+03
# 2025-03-31 15:59:37,955 __main__ 0/1 INFO :: Iteration=11, Time=6.720844e+04, dt=6.109858e+03
# 2025-03-31 15:59:38,239 __main__ 0/1 INFO :: Iteration=21, Time=1.283070e+05, dt=6.109858e+03
# 2025-03-31 15:59:38,516 __main__ 0/1 INFO :: Iteration=31, Time=1.894056e+05, dt=6.109858e+03
# 2025-03-31 15:59:38,790 __main__ 0/1 INFO :: Iteration=41, Time=2.505042e+05, dt=6.109858e+03
# 2025-03-31 15:59:39,066 __main__ 0/1 INFO :: Iteration=51, Time=3.116028e+05, dt=6.109858e+03
# 2025-03-31 15:59:39,354 __main__ 0/1 INFO :: Iteration=61, Time=3.727014e+05, dt=6.109858e+03
# 2025-03-31 15:59:39,631 __main__ 0/1 INFO :: Iteration=71, Time=4.338000e+05, dt=6.109858e+03
# 2025-03-31 15:59:39,905 __main__ 0/1 INFO :: Iteration=81, Time=4.948985e+05, dt=6.109858e+03
# 2025-03-31 15:59:40,179 __main__ 0/1 INFO :: Iteration=91, Time=5.559971e+05, dt=6.109858e+03
# 2025-03-31 15:59:40,454 __main__ 0/1 INFO :: Iteration=101, Time=6.170957e+05, dt=6.109858e+03
# 2025-03-31 15:59:40,728 __main__ 0/1 INFO :: Iteration=111, Time=6.781943e+05, dt=6.109858e+03
# 2025-03-31 15:59:41,002 __main__ 0/1 INFO :: Iteration=121, Time=7.392929e+05, dt=6.109858e+03
# 2025-03-31 15:59:41,275 __main__ 0/1 INFO :: Iteration=131, Time=8.003915e+05, dt=6.109858e+03
# 2025-03-31 15:59:41,550 __main__ 0/1 INFO :: Iteration=141, Time=8.614900e+05, dt=6.109858e+03
# 2025-03-31 15:59:41,823 __main__ 0/1 INFO :: Iteration=151, Time=9.225886e+05, dt=6.109858e+03
# 2025-03-31 15:59:42,097 __main__ 0/1 INFO :: Iteration=161, Time=9.836872e+05, dt=6.109858e+03
# 2025-03-31 15:59:42,374 __main__ 0/1 INFO :: Iteration=171, Time=1.044786e+06, dt=6.109858e+03
# 2025-03-31 15:59:42,650 __main__ 0/1 INFO :: Iteration=181, Time=1.105884e+06, dt=6.109858e+03
# 2025-03-31 15:59:42,927 __main__ 0/1 INFO :: Iteration=191, Time=1.166983e+06, dt=6.109858e+03
# 2025-03-31 15:59:43,203 __main__ 0/1 INFO :: Iteration=201, Time=1.228082e+06, dt=6.109858e+03
# 2025-03-31 15:59:43,478 __main__ 0/1 INFO :: Iteration=211, Time=1.289180e+06, dt=6.109858e+03
# 2025-03-31 15:59:43,751 __main__ 0/1 INFO :: Iteration=221, Time=1.350279e+06, dt=6.109858e+03
# 2025-03-31 15:59:44,025 __main__ 0/1 INFO :: Iteration=231, Time=1.411377e+06, dt=6.109858e+03
# 2025-03-31 15:59:44,301 __main__ 0/1 INFO :: Iteration=241, Time=1.472476e+06, dt=6.109858e+03
# 2025-03-31 15:59:44,577 __main__ 0/1 INFO :: Iteration=251, Time=1.533574e+06, dt=6.109858e+03
# 2025-03-31 15:59:44,851 __main__ 0/1 INFO :: Iteration=261, Time=1.594673e+06, dt=6.109858e+03
# 2025-03-31 15:59:45,141 __main__ 0/1 INFO :: Iteration=271, Time=1.655772e+06, dt=6.109858e+03
# 2025-03-31 15:59:45,423 __main__ 0/1 INFO :: Iteration=281, Time=1.716870e+06, dt=6.109858e+03
# 2025-03-31 15:59:45,708 __main__ 0/1 INFO :: Iteration=291, Time=1.777969e+06, dt=6.109858e+03
# 2025-03-31 15:59:45,985 __main__ 0/1 INFO :: Iteration=301, Time=1.839067e+06, dt=6.109858e+03
# 2025-03-31 15:59:46,259 __main__ 0/1 INFO :: Iteration=311, Time=1.900166e+06, dt=6.109858e+03
# 2025-03-31 15:59:46,533 __main__ 0/1 INFO :: Iteration=321, Time=1.961265e+06, dt=6.109858e+03
# 2025-03-31 15:59:46,808 __main__ 0/1 INFO :: Iteration=331, Time=2.022363e+06, dt=6.109858e+03
# 2025-03-31 15:59:47,092 __main__ 0/1 INFO :: Iteration=341, Time=2.083462e+06, dt=6.109858e+03
# 2025-03-31 15:59:47,381 __main__ 0/1 INFO :: Iteration=351, Time=2.144560e+06, dt=6.109858e+03
# 2025-03-31 15:59:47,654 __main__ 0/1 INFO :: Iteration=361, Time=2.205659e+06, dt=6.109858e+03
# 2025-03-31 15:59:47,928 __main__ 0/1 INFO :: Iteration=371, Time=2.266758e+06, dt=6.109858e+03
# 2025-03-31 15:59:48,202 __main__ 0/1 INFO :: Iteration=381, Time=2.327856e+06, dt=6.109858e+03
# 2025-03-31 15:59:48,482 __main__ 0/1 INFO :: Iteration=391, Time=2.388955e+06, dt=6.109858e+03
# 2025-03-31 15:59:48,809 __main__ 0/1 INFO :: Iteration=401, Time=2.450053e+06, dt=6.109858e+03
# 2025-03-31 15:59:49,085 __main__ 0/1 INFO :: Iteration=411, Time=2.511152e+06, dt=6.109858e+03
# 2025-03-31 15:59:49,360 __main__ 0/1 INFO :: Iteration=421, Time=2.572250e+06, dt=6.109858e+03
# 2025-03-31 15:59:49,644 __main__ 0/1 INFO :: Iteration=431, Time=2.633349e+06, dt=6.109858e+03
# 2025-03-31 15:59:49,922 __main__ 0/1 INFO :: Iteration=441, Time=2.694448e+06, dt=6.109858e+03
# 2025-03-31 15:59:50,205 __main__ 0/1 INFO :: Iteration=451, Time=2.755546e+06, dt=6.109858e+03
# 2025-03-31 15:59:50,502 __main__ 0/1 INFO :: Iteration=461, Time=2.816645e+06, dt=6.109858e+03
# 2025-03-31 15:59:50,794 __main__ 0/1 INFO :: Iteration=471, Time=2.877743e+06, dt=6.109858e+03
# 2025-03-31 15:59:51,073 __main__ 0/1 INFO :: Iteration=481, Time=2.938842e+06, dt=6.109858e+03
# 2025-03-31 15:59:51,347 __main__ 0/1 INFO :: Iteration=491, Time=2.999941e+06, dt=6.109858e+03
# 2025-03-31 15:59:51,628 __main__ 0/1 INFO :: Iteration=501, Time=3.061039e+06, dt=6.109858e+03
# 2025-03-31 15:59:51,908 __main__ 0/1 INFO :: Iteration=511, Time=3.122138e+06, dt=6.109858e+03
# 2025-03-31 15:59:52,201 __main__ 0/1 INFO :: Iteration=521, Time=3.183236e+06, dt=6.109858e+03
# 2025-03-31 15:59:52,479 __main__ 0/1 INFO :: Iteration=531, Time=3.244335e+06, dt=6.109858e+03
# 2025-03-31 15:59:52,752 __main__ 0/1 INFO :: Iteration=541, Time=3.305433e+06, dt=6.109858e+03
# 2025-03-31 15:59:53,029 __main__ 0/1 INFO :: Iteration=551, Time=3.366532e+06, dt=6.109858e+03
# 2025-03-31 15:59:53,303 __main__ 0/1 INFO :: Iteration=561, Time=3.427631e+06, dt=6.109858e+03
# 2025-03-31 15:59:53,578 __main__ 0/1 INFO :: Iteration=571, Time=3.488729e+06, dt=6.109858e+03
# 2025-03-31 15:59:53,872 __main__ 0/1 INFO :: Iteration=581, Time=3.549828e+06, dt=6.109858e+03
# 2025-03-31 15:59:54,147 __main__ 0/1 INFO :: Iteration=591, Time=3.610926e+06, dt=6.109858e+03
# 2025-03-31 15:59:54,422 __main__ 0/1 INFO :: Iteration=601, Time=3.672025e+06, dt=6.109858e+03
# 2025-03-31 15:59:54,696 __main__ 0/1 INFO :: Iteration=611, Time=3.733124e+06, dt=6.109858e+03
# 2025-03-31 15:59:54,969 __main__ 0/1 INFO :: Iteration=621, Time=3.794222e+06, dt=6.109858e+03
# 2025-03-31 15:59:55,259 __main__ 0/1 INFO :: Iteration=631, Time=3.855321e+06, dt=6.109858e+03
# 2025-03-31 15:59:55,537 __main__ 0/1 INFO :: Iteration=641, Time=3.916419e+06, dt=6.109858e+03
# 2025-03-31 15:59:55,810 __main__ 0/1 INFO :: Iteration=651, Time=3.977518e+06, dt=6.109858e+03
# 2025-03-31 15:59:56,084 __main__ 0/1 INFO :: Iteration=661, Time=4.038616e+06, dt=6.109858e+03
# 2025-03-31 15:59:56,361 __main__ 0/1 INFO :: Iteration=671, Time=4.099715e+06, dt=6.109858e+03
# 2025-03-31 15:59:56,638 __main__ 0/1 INFO :: Iteration=681, Time=4.160814e+06, dt=6.109858e+03
# 2025-03-31 15:59:56,917 __main__ 0/1 INFO :: Iteration=691, Time=4.221912e+06, dt=6.109858e+03
# 2025-03-31 15:59:57,198 __main__ 0/1 INFO :: Iteration=701, Time=4.283011e+06, dt=6.109858e+03
# 2025-03-31 15:59:57,391 solvers 0/1 INFO :: Simulation stop time reached.
# 2025-03-31 15:59:57,392 solvers 0/1 INFO :: Final iteration: 708
# 2025-03-31 15:59:57,392 solvers 0/1 INFO :: Final sim time: 4325779.812500624
# 2025-03-31 15:59:57,392 solvers 0/1 INFO :: Setup time (init - iter 0): 1.519 sec
# 2025-03-31 15:59:57,393 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.396 sec
# 2025-03-31 15:59:57,393 solvers 0/1 INFO :: Run time (iter 10-end): 19.46 sec
# 2025-03-31 15:59:57,393 solvers 0/1 INFO :: CPU time (iter 10-end): 0.005407 cpu-hr
# 2025-03-31 15:59:57,393 solvers 0/1 INFO :: Speed: 3.47e+06 mode-stages/cpu-sec

# %% [markdown]
# ## Visualize the simulation output

# %%
import h5py
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import dedalus.public as d3
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import os
from PIL import Image
from mpl_toolkits.axes_grid1 import make_axes_locatable
import xarray as xr

# %%
simdata = './snapshots_RSWE_reduced/snapshots_RSWE_reduced_s1.h5'

# %%
# See what is in the data files
with h5py.File(simdata, mode='r') as file:
    a_group_key = list(file.keys())
    print(a_group_key)
    
    print(file['scales'])
    print(list(file['scales']))
    print(file['tasks'])
    print(list(file['tasks']))
# Out:
# ['scales', 'tasks']
# <HDF5 group "/scales" (8 members)>
# ['constant', 'iteration', 'sim_time', 'timestep', 'wall_time', 'write_number', 'x_hash_0b7dfb2e65990127464432e8c7f9ce562b7d93bd', 'y_hash_0b7dfb2e65990127464432e8c7f9ce562b7d93bd']
# <HDF5 group "/tasks" (4 members)>
# ['divergence', 'height', 'uvec', 'vorticity']

# %%
# Actually read in data files
with h5py.File(simdata, mode='r') as file:
    
    h_data = np.squeeze(np.array(file['tasks']['height']))
    print('h shape: ' + str(h_data.shape))
    u_data = np.squeeze(np.array(file['tasks']['uvec']))
    print('u_data: ' + str(u_data.shape))
    vort_data = np.squeeze(np.array(file['tasks']['vorticity']))
    print('vort_data: ' + str(vort_data.shape))
    div_data = np.squeeze(np.array(file['tasks']['divergence']))
    print('div_data: ' + str(div_data.shape))
    #vort_data = np.squeeze(np.array(file['tasks']['vorticity']))
    #div_data = np.squeeze(np.array(file['tasks']['divergence']))
    
    sim_time_ary = np.array(file['scales']['sim_time'])
    print(sim_time_ary.shape)
    
    x = np.array(file['scales'][list(file['scales'])[-2]])
    y = np.array(file['scales'][list(file['scales'])[-1]])
# Out:
# h shape: (708, 128, 128)
# u_data: (708, 2, 128, 128)
# vort_data: (708, 128, 128)
# div_data: (708, 128, 128)
# (708,)

# %%
# Put data in xarray, as it is nice way to keep things organized
ds_sim = xr.Dataset()

ds_sim['h'] = xr.DataArray(h_data, coords = {'time':sim_time_ary, 'x':x, 'y':y})
ds_sim['u'] = xr.DataArray(u_data[:,0,:,:].squeeze(), coords = {'time':sim_time_ary, 'x':y, 'y':y})
ds_sim['v'] = xr.DataArray(u_data[:,1,:,:].squeeze(), coords = {'time':sim_time_ary, 'x':x, 'y':y})

ds_sim['vort'] = xr.DataArray(vort_data, coords = {'time':sim_time_ary, 'x':x, 'y':y})
ds_sim['div'] = xr.DataArray(div_data, coords = {'time':sim_time_ary, 'x':x, 'y':y})

# %%
ds_sim
# Out:
# <xarray.Dataset> Size: 464MB
# Dimensions:  (time: 708, x: 128, y: 128)
# Coordinates:
#   * time     (time) float64 6kB 0.0 6.11e+03 1.222e+04 ... 4.314e+06 4.32e+06
#   * x        (x) float64 1kB -3e+06 -2.953e+06 ... 2.906e+06 2.953e+06
#   * y        (y) float64 1kB -3e+06 -2.953e+06 ... 2.906e+06 2.953e+06
# Data variables:
#     h        (time, x, y) float64 93MB 300.0 300.0 300.0 ... 300.0 300.0 300.0
#     u        (time, x, y) float64 93MB 0.0 0.0 0.0 ... 6.115e-06 4.354e-06
#     v        (time, x, y) float64 93MB 0.0 0.0 0.0 ... 2.594e-06 3.588e-07
#     vort     (time, x, y) float64 93MB 0.0 0.0 0.0 ... 8.346e-11 8.469e-11
#     div      (time, x, y) float64 93MB 0.0 0.0 0.0 ... -9.081e-11 -9.882e-11

# %%
def create_animation(fun, idx, filename='my-animation.gif', dpi=200, FPS=18, loop=0):
    '''
    See https://pythonprogramming.altervista.org/png-to-gif/
    fun(i) - a function creating one snapshot, has only one input:
        - number of frame i
    idx - range of frames, i in idx
    FPS - frames per second
    filename - animation name
    dpi - set 300 or so to increase quality
    loop - number of repeats of the gif
    '''
    frames = []
    for i in idx:
        fun(i)
        plt.savefig('.frame.png', dpi=dpi, bbox_inches='tight')
        plt.close()
        frames.append(Image.open('.frame.png').convert('RGB'))
        print(f'Frame {i} is created', end='\r')
    os.system('rm .frame.png')
    # How long to persist one frame in milliseconds to have a desired FPS
    duration = 1000 / FPS
    print(f'Animation at FPS={FPS} will last for {len(idx)/FPS} seconds')
    frames[0].save(
        filename, format='GIF',
        append_images=frames[1:],
        save_all=True,
        duration=duration,
        loop=loop)

# %%
# This function needs to be modified as needed if you want to make other movies
def plot_fun(time_idx): 
    vmin= H - A/4
    vmax = H + A/4
    fig = plt.figure(figsize=(8, 3))

    plt.subplot(1,2,1)
    ds_sim.h.isel(time=time_idx).plot(x='x', vmin=vmin, vmax=vmax)
    plt.gca().set_aspect('equal')
    plt.title("")

    plt.subplot(1,2,2)
    (ds_sim.vort).isel(time=time_idx).plot(x='x', vmin = -0.1e-8)
    plt.gca().set_aspect('equal')
    
    plt.title(f"{sim_time_ary[time_idx]/60/60:.2f} hours")

    plt.tight_layout()

# %%
plot_fun(0)

# %%
plot_fun(5)

# %%
plot_fun(-1)

# %%
fname = 'SW_RSWE_rigid_lid.gif'
create_animation(plot_fun, range(0, len(sim_time_ary), 1), filename=fname)
# Out:
# Animation at FPS=18 will last for 39.333333333333336 seconds
