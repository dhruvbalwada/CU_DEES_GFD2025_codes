# %% [markdown]
# # Internal-Gravity Waves
#
# In this code we will solve the boussinesq equations linearized around a state of rest, which can be written in vector form as:
# $$
# \frac{\partial \mathbf{u}}{\partial t} + \nabla \phi - b \hat{k} = 0
# $$
#
# $$
# \nabla \cdot \mathbf{u} =0
# $$
#
# $$
# \frac{\partial b}{\partial t} + N^2 \mathbf{u} \cdot \hat{k} = 0
# $$
#
# where $\mathbf{u} = (u, w)$ is the velocity in the 2D x-z plane, b is the buoyancy field, and $\phi$ is the dynamics pressure. $N^2$ is the background buoyancy field (constant here, but doesn't need to be in general).
#
# > For more context see section 2.10 in the Vallis book.
#
#
# Here we will solve the equations for a simple scenario.
#
# Here we also add another equation, which explain the evolution of a passive tracer.
# $$
# \frac{\partial C}{\partial t} + \mathbf{u} \cdot \nabla C = \kappa \nabla^2 C
# $$
# This is the advection-diffusion equation.

# %%
import numpy as np
import dedalus.public as d3
import logging
logger = logging.getLogger(__name__)

# %%
# Parameters
Lx, Lz = 4, 1
Nx, Nz = 256, 64

N2= 1 # You may need to change

dealias = 3/2
stop_sim_time = 75
timestepper = d3.RK222
max_timestep = 0.125
dtype = np.float64

kappa = 1

# %%
# Bases
coords = d3.CartesianCoordinates('x', 'z')
dist = d3.Distributor(coords, dtype=dtype)
xbasis = d3.RealFourier(coords['x'], size=Nx, bounds=(-Lx, Lx), dealias=dealias)
zbasis = d3.RealFourier(coords['z'], size=Nz, bounds=(-Lz, Lz), dealias=dealias)

# Fields
p = dist.Field(name='p', bases=(xbasis,zbasis))
b = dist.Field(name='b', bases=(xbasis,zbasis))
u = dist.VectorField(coords, name='u', bases=(xbasis,zbasis))
C = dist.Field(name='C', bases=(xbasis,zbasis))
#w = dist.Field(name='w', bases=(xbasis,zbasis))

tau_p = dist.Field(name='tau_p')

x, z = dist.local_grids(xbasis, zbasis)
ex, ez = coords.unit_vector_fields(dist)

# %% [markdown]
# We will force the system with a time varying forcing (sinusoidal in time), which will be applied to a local region (localized using a gaussian).
#
# The goal will be to see how waves emanate from this forcing region.

# %%
# Setup Forcing 
Fxz = dist.Field(name='Fxz', bases=(xbasis,zbasis))

sigma = 0.08 # sets the size of the forcing region.
Fxz['g'] = np.exp(-((x)**2 + (z)**2) / (2 * sigma**2))

t = dist.Field()
forcing_freq = 0.6*N2 # You may need to change (we are setting this relative to N2 for physical meangingfulness)
Ft = np.sin(forcing_freq*t)

# %%
from dedalus.extras.plot_tools import plot_bot_2d
plot_bot_2d(Fxz,title="Region where forcing is applied");

# %%
problem = d3.IVP([p, b, u, tau_p, C], time=t, namespace=locals())

# %% [markdown]
# In principle the system can solved quite easily, using Dedalus. Notice that the equations are entered in almost readable form.
#
# >@ is the dot product, * is just simple multiplication.
#
# Also notice that we are applying the forcing only to the vertical momentum equation.

# %%
problem.add_equation("dt(u) + grad(p) - b*ez = (Fxz*Ft)*ez")
problem.add_equation("div(u) + tau_p = 0")
problem.add_equation("dt(b) + N2*(u@ez) = 0")
problem.add_equation("integ(p) = 0");
problem.add_equation("dt(C) - kappa*lap(C)= - u@grad(C)")
# Out:
# {'LHS': Add(dt(<Field 5197616592>), Mul(-1, Lap(<Field 5197616592>))),
#  'RHS': Dot(Mul(-1, <Field 4593228368>), Grad(<Field 5197616592>)),
#  'condition': 'True',
#  'tensorsig': (),
#  'dtype': dtype('float64'),
#  'M': <Field 5197616592>,
#  'L': Mul(-1, Lap(<Field 5197616592>)),
#  'F': Dot(Mul(-1, <Field 4593228368>), Grad(<Field 5197616592>)),
#  'domain': <dedalus.core.domain.Domain at 0x135cd4c50>,
#  'matrix_dependence': array([ True,  True]),
#  'matrix_coupling': array([False, False])}

# %%
# Solver
solver = problem.build_solver(timestepper)
solver.stop_sim_time = stop_sim_time
# Out:
# 2025-02-19 11:57:08,029 subsystems 0/1 INFO :: Building subproblem matrices 1/128 (~1%) Elapsed: 0s, Remaining: 3s, Rate: 4.3e+01/s
# 2025-02-19 11:57:08,230 subsystems 0/1 INFO :: Building subproblem matrices 13/128 (~10%) Elapsed: 0s, Remaining: 2s, Rate: 5.8e+01/s
# 2025-02-19 11:57:08,444 subsystems 0/1 INFO :: Building subproblem matrices 26/128 (~20%) Elapsed: 0s, Remaining: 2s, Rate: 5.9e+01/s
# 2025-02-19 11:57:08,650 subsystems 0/1 INFO :: Building subproblem matrices 39/128 (~30%) Elapsed: 1s, Remaining: 1s, Rate: 6.1e+01/s
# 2025-02-19 11:57:08,891 subsystems 0/1 INFO :: Building subproblem matrices 52/128 (~41%) Elapsed: 1s, Remaining: 1s, Rate: 5.9e+01/s
# 2025-02-19 11:57:09,089 subsystems 0/1 INFO :: Building subproblem matrices 65/128 (~51%) Elapsed: 1s, Remaining: 1s, Rate: 6.0e+01/s
# 2025-02-19 11:57:09,285 subsystems 0/1 INFO :: Building subproblem matrices 78/128 (~61%) Elapsed: 1s, Remaining: 1s, Rate: 6.1e+01/s
# 2025-02-19 11:57:09,480 subsystems 0/1 INFO :: Building subproblem matrices 91/128 (~71%) Elapsed: 1s, Remaining: 1s, Rate: 6.2e+01/s
# 2025-02-19 11:57:09,681 subsystems 0/1 INFO :: Building subproblem matrices 104/128 (~81%) Elapsed: 2s, Remaining: 0s, Rate: 6.2e+01/s
# 2025-02-19 11:57:09,873 subsystems 0/1 INFO :: Building subproblem matrices 117/128 (~91%) Elapsed: 2s, Remaining: 0s, Rate: 6.3e+01/s
# 2025-02-19 11:57:10,035 subsystems 0/1 INFO :: Building subproblem matrices 128/128 (~100%) Elapsed: 2s, Remaining: 0s, Rate: 6.3e+01/s

# %%
xn = list(np.linspace(-Lx, Lx, 4))
zn = list(np.linspace(-Lz, Lz, 3))
sigma_tracer = 0.3
C['g'] = 0
for xo in xn:
    for zo in zn:
        
        gauss_bump = np.exp( - ((x -  xo)**2 + (z - zo)**2) / (2 * sigma_tracer**2) )

        C['g'] = C['g'] + gauss_bump

# %%
from dedalus.extras.plot_tools import plot_bot_2d
plot_bot_2d(C,title="Initial tracer conc");

# %% [markdown]
# The next few lines setup the way that the data will be saved.

# %%
# Analysis
sim_dt = 0.25
max_writes = stop_sim_time/sim_dt
data_fname = 'snapshots'
snapshots = solver.evaluator.add_file_handler(data_fname, 
                                              sim_dt=sim_dt, 
                                              max_writes=max_writes)
snapshots.add_task(b, name='buoyancy')
snapshots.add_task(u, name='uvec')
snapshots.add_task(p, name='pressure')
snapshots.add_task(C, name='tracer')
#snapshots.add_task(-d3.div(d3.skew(u)), name='vorticity')

# %%
# CFL (adapt time step as needed)
CFL = d3.CFL(solver, initial_dt=max_timestep, cadence=10, safety=0.5, threshold=0.05,
             max_change=1.5, min_change=0.5, max_dt=max_timestep)
CFL.add_velocity(u)

# %%
# Main loop
startup_iter = 10
try:
    logger.info('Starting main loop')
    while solver.proceed:
        timestep = CFL.compute_timestep()
        solver.step(timestep)
        if (solver.iteration-1) % 10 == 0:
            
            logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
except:
    logger.error('Exception raised, triggering end of main loop.')
    raise
finally:
    solver.log_stats()
# Out:
# 2025-02-19 11:57:10,306 __main__ 0/1 INFO :: Starting main loop
# 2025-02-19 11:57:11,307 __main__ 0/1 INFO :: Iteration=1, Time=1.250000e-01, dt=1.250000e-01
# 2025-02-19 11:57:11,542 __main__ 0/1 INFO :: Iteration=11, Time=1.375000e+00, dt=1.250000e-01
# 2025-02-19 11:57:11,872 __main__ 0/1 INFO :: Iteration=21, Time=2.140616e+00, dt=7.656157e-02
# 2025-02-19 11:57:12,179 __main__ 0/1 INFO :: Iteration=31, Time=2.523423e+00, dt=3.828078e-02
# 2025-02-19 11:57:12,499 __main__ 0/1 INFO :: Iteration=41, Time=2.841419e+00, dt=3.179953e-02
# 2025-02-19 11:57:12,715 __main__ 0/1 INFO :: Iteration=51, Time=3.159414e+00, dt=3.179953e-02
# 2025-02-19 11:57:12,913 __main__ 0/1 INFO :: Iteration=61, Time=3.477409e+00, dt=3.179953e-02
# 2025-02-19 11:57:13,229 __main__ 0/1 INFO :: Iteration=71, Time=3.851266e+00, dt=3.738568e-02
# 2025-02-19 11:57:13,542 __main__ 0/1 INFO :: Iteration=81, Time=4.386762e+00, dt=5.354961e-02
# 2025-02-19 11:57:13,863 __main__ 0/1 INFO :: Iteration=91, Time=5.149437e+00, dt=7.626745e-02
# 2025-02-19 11:57:14,177 __main__ 0/1 INFO :: Iteration=101, Time=5.536600e+00, dt=3.871635e-02
# 2025-02-19 11:57:14,491 __main__ 0/1 INFO :: Iteration=111, Time=5.779481e+00, dt=2.428811e-02
# 2025-02-19 11:57:14,787 __main__ 0/1 INFO :: Iteration=121, Time=5.983232e+00, dt=2.037508e-02
# 2025-02-19 11:57:15,094 __main__ 0/1 INFO :: Iteration=131, Time=6.167180e+00, dt=1.839477e-02
# 2025-02-19 11:57:15,394 __main__ 0/1 INFO :: Iteration=141, Time=6.339276e+00, dt=1.720965e-02
# 2025-02-19 11:57:15,585 __main__ 0/1 INFO :: Iteration=151, Time=6.511373e+00, dt=1.720965e-02
# 2025-02-19 11:57:15,894 __main__ 0/1 INFO :: Iteration=161, Time=6.672019e+00, dt=1.606459e-02
# 2025-02-19 11:57:16,095 __main__ 0/1 INFO :: Iteration=171, Time=6.832665e+00, dt=1.606459e-02
# 2025-02-19 11:57:16,292 __main__ 0/1 INFO :: Iteration=181, Time=6.993310e+00, dt=1.606459e-02
# 2025-02-19 11:57:16,494 __main__ 0/1 INFO :: Iteration=191, Time=7.153956e+00, dt=1.606459e-02
# 2025-02-19 11:57:16,709 __main__ 0/1 INFO :: Iteration=201, Time=7.314602e+00, dt=1.606459e-02
# 2025-02-19 11:57:17,027 __main__ 0/1 INFO :: Iteration=211, Time=7.491937e+00, dt=1.773347e-02
# 2025-02-19 11:57:17,345 __main__ 0/1 INFO :: Iteration=221, Time=7.683092e+00, dt=1.911555e-02
# 2025-02-19 11:57:17,669 __main__ 0/1 INFO :: Iteration=231, Time=7.896182e+00, dt=2.130900e-02
# 2025-02-19 11:57:17,981 __main__ 0/1 INFO :: Iteration=241, Time=8.146851e+00, dt=2.506691e-02
# 2025-02-19 11:57:18,294 __main__ 0/1 INFO :: Iteration=251, Time=8.439888e+00, dt=2.930370e-02
# 2025-02-19 11:57:18,494 __main__ 0/1 INFO :: Iteration=261, Time=8.732925e+00, dt=2.930370e-02
# 2025-02-19 11:57:18,807 __main__ 0/1 INFO :: Iteration=271, Time=9.044453e+00, dt=3.115273e-02
# 2025-02-19 11:57:19,007 __main__ 0/1 INFO :: Iteration=281, Time=9.355980e+00, dt=3.115273e-02
# 2025-02-19 11:57:19,211 __main__ 0/1 INFO :: Iteration=291, Time=9.667507e+00, dt=3.115273e-02
# 2025-02-19 11:57:19,544 __main__ 0/1 INFO :: Iteration=301, Time=9.945824e+00, dt=2.783173e-02
# 2025-02-19 11:57:19,847 __main__ 0/1 INFO :: Iteration=311, Time=1.018688e+01, dt=2.410600e-02
# 2025-02-19 11:57:20,156 __main__ 0/1 INFO :: Iteration=321, Time=1.039894e+01, dt=2.120595e-02
# 2025-02-19 11:57:20,456 __main__ 0/1 INFO :: Iteration=331, Time=1.059469e+01, dt=1.957470e-02
# 2025-02-19 11:57:20,657 __main__ 0/1 INFO :: Iteration=341, Time=1.079044e+01, dt=1.957470e-02
# 2025-02-19 11:57:20,958 __main__ 0/1 INFO :: Iteration=351, Time=1.097230e+01, dt=1.818663e-02
# 2025-02-19 11:57:21,162 __main__ 0/1 INFO :: Iteration=361, Time=1.115417e+01, dt=1.818663e-02
# 2025-02-19 11:57:21,360 __main__ 0/1 INFO :: Iteration=371, Time=1.133604e+01, dt=1.818663e-02
# 2025-02-19 11:57:21,553 __main__ 0/1 INFO :: Iteration=381, Time=1.151790e+01, dt=1.818663e-02
# 2025-02-19 11:57:21,865 __main__ 0/1 INFO :: Iteration=391, Time=1.171175e+01, dt=1.938424e-02
# 2025-02-19 11:57:22,177 __main__ 0/1 INFO :: Iteration=401, Time=1.191693e+01, dt=2.051846e-02
# 2025-02-19 11:57:22,496 __main__ 0/1 INFO :: Iteration=411, Time=1.213902e+01, dt=2.220939e-02
# 2025-02-19 11:57:22,799 __main__ 0/1 INFO :: Iteration=421, Time=1.238674e+01, dt=2.477188e-02
# 2025-02-19 11:57:23,000 __main__ 0/1 INFO :: Iteration=431, Time=1.263446e+01, dt=2.477188e-02
# 2025-02-19 11:57:23,202 __main__ 0/1 INFO :: Iteration=441, Time=1.288218e+01, dt=2.477188e-02
# 2025-02-19 11:57:23,409 __main__ 0/1 INFO :: Iteration=451, Time=1.312990e+01, dt=2.477188e-02
# 2025-02-19 11:57:23,612 __main__ 0/1 INFO :: Iteration=461, Time=1.337762e+01, dt=2.477188e-02
# 2025-02-19 11:57:23,819 __main__ 0/1 INFO :: Iteration=471, Time=1.362534e+01, dt=2.477188e-02
# 2025-02-19 11:57:24,125 __main__ 0/1 INFO :: Iteration=481, Time=1.388714e+01, dt=2.618011e-02
# 2025-02-19 11:57:24,327 __main__ 0/1 INFO :: Iteration=491, Time=1.414894e+01, dt=2.618011e-02
# 2025-02-19 11:57:24,632 __main__ 0/1 INFO :: Iteration=501, Time=1.442758e+01, dt=2.786392e-02
# 2025-02-19 11:57:24,840 __main__ 0/1 INFO :: Iteration=511, Time=1.470622e+01, dt=2.786392e-02
# 2025-02-19 11:57:25,146 __main__ 0/1 INFO :: Iteration=521, Time=1.501381e+01, dt=3.075949e-02
# 2025-02-19 11:57:25,462 __main__ 0/1 INFO :: Iteration=531, Time=1.534236e+01, dt=3.285427e-02
# 2025-02-19 11:57:25,769 __main__ 0/1 INFO :: Iteration=541, Time=1.569184e+01, dt=3.494832e-02
# 2025-02-19 11:57:26,074 __main__ 0/1 INFO :: Iteration=551, Time=1.601720e+01, dt=3.253658e-02
# 2025-02-19 11:57:26,390 __main__ 0/1 INFO :: Iteration=561, Time=1.632544e+01, dt=3.082373e-02
# 2025-02-19 11:57:26,692 __main__ 0/1 INFO :: Iteration=571, Time=1.661708e+01, dt=2.916350e-02
# 2025-02-19 11:57:26,900 __main__ 0/1 INFO :: Iteration=581, Time=1.690871e+01, dt=2.916350e-02
# 2025-02-19 11:57:27,203 __main__ 0/1 INFO :: Iteration=591, Time=1.717673e+01, dt=2.680195e-02
# 2025-02-19 11:57:27,408 __main__ 0/1 INFO :: Iteration=601, Time=1.744475e+01, dt=2.680195e-02
# 2025-02-19 11:57:27,605 __main__ 0/1 INFO :: Iteration=611, Time=1.771277e+01, dt=2.680195e-02
# 2025-02-19 11:57:27,802 __main__ 0/1 INFO :: Iteration=621, Time=1.798079e+01, dt=2.680195e-02
# 2025-02-19 11:57:27,998 __main__ 0/1 INFO :: Iteration=631, Time=1.824881e+01, dt=2.680195e-02
# 2025-02-19 11:57:28,203 __main__ 0/1 INFO :: Iteration=641, Time=1.851683e+01, dt=2.680195e-02
# 2025-02-19 11:57:28,517 __main__ 0/1 INFO :: Iteration=651, Time=1.880310e+01, dt=2.862746e-02
# 2025-02-19 11:57:28,721 __main__ 0/1 INFO :: Iteration=661, Time=1.908938e+01, dt=2.862746e-02
# 2025-02-19 11:57:28,922 __main__ 0/1 INFO :: Iteration=671, Time=1.937565e+01, dt=2.862746e-02
# 2025-02-19 11:57:29,226 __main__ 0/1 INFO :: Iteration=681, Time=1.968556e+01, dt=3.099092e-02
# 2025-02-19 11:57:29,425 __main__ 0/1 INFO :: Iteration=691, Time=1.999547e+01, dt=3.099092e-02
# 2025-02-19 11:57:29,742 __main__ 0/1 INFO :: Iteration=701, Time=2.033323e+01, dt=3.377633e-02
# 2025-02-19 11:57:30,051 __main__ 0/1 INFO :: Iteration=711, Time=2.069121e+01, dt=3.579786e-02
# 2025-02-19 11:57:30,262 __main__ 0/1 INFO :: Iteration=721, Time=2.104919e+01, dt=3.579786e-02
# 2025-02-19 11:57:30,569 __main__ 0/1 INFO :: Iteration=731, Time=2.130998e+01, dt=2.607908e-02
# 2025-02-19 11:57:30,875 __main__ 0/1 INFO :: Iteration=741, Time=2.153226e+01, dt=2.222751e-02
# 2025-02-19 11:57:31,175 __main__ 0/1 INFO :: Iteration=751, Time=2.173403e+01, dt=2.017692e-02
# 2025-02-19 11:57:31,480 __main__ 0/1 INFO :: Iteration=761, Time=2.192350e+01, dt=1.894782e-02
# 2025-02-19 11:57:31,703 __main__ 0/1 INFO :: Iteration=771, Time=2.211298e+01, dt=1.894782e-02
# 2025-02-19 11:57:32,026 __main__ 0/1 INFO :: Iteration=781, Time=2.229106e+01, dt=1.780818e-02
# 2025-02-19 11:57:32,222 __main__ 0/1 INFO :: Iteration=791, Time=2.246915e+01, dt=1.780818e-02
# 2025-02-19 11:57:32,430 __main__ 0/1 INFO :: Iteration=801, Time=2.264723e+01, dt=1.780818e-02
# 2025-02-19 11:57:32,634 __main__ 0/1 INFO :: Iteration=811, Time=2.282531e+01, dt=1.780818e-02
# 2025-02-19 11:57:32,935 __main__ 0/1 INFO :: Iteration=821, Time=2.301632e+01, dt=1.910115e-02
# 2025-02-19 11:57:33,247 __main__ 0/1 INFO :: Iteration=831, Time=2.321989e+01, dt=2.035715e-02
# 2025-02-19 11:57:33,554 __main__ 0/1 INFO :: Iteration=841, Time=2.344341e+01, dt=2.235153e-02
# 2025-02-19 11:57:33,893 __main__ 0/1 INFO :: Iteration=851, Time=2.370025e+01, dt=2.568379e-02
# 2025-02-19 11:57:34,204 __main__ 0/1 INFO :: Iteration=861, Time=2.400485e+01, dt=3.046048e-02
# 2025-02-19 11:57:34,420 __main__ 0/1 INFO :: Iteration=871, Time=2.430946e+01, dt=3.046048e-02
# 2025-02-19 11:57:34,633 __main__ 0/1 INFO :: Iteration=881, Time=2.461406e+01, dt=3.046048e-02
# 2025-02-19 11:57:34,838 __main__ 0/1 INFO :: Iteration=891, Time=2.491866e+01, dt=3.046048e-02
# 2025-02-19 11:57:35,152 __main__ 0/1 INFO :: Iteration=901, Time=2.524064e+01, dt=3.219775e-02
# 2025-02-19 11:57:35,375 __main__ 0/1 INFO :: Iteration=911, Time=2.556262e+01, dt=3.219775e-02
# 2025-02-19 11:57:35,687 __main__ 0/1 INFO :: Iteration=921, Time=2.585210e+01, dt=2.894760e-02
# 2025-02-19 11:57:36,001 __main__ 0/1 INFO :: Iteration=931, Time=2.609636e+01, dt=2.442639e-02
# 2025-02-19 11:57:36,317 __main__ 0/1 INFO :: Iteration=941, Time=2.631578e+01, dt=2.194251e-02
# 2025-02-19 11:57:36,630 __main__ 0/1 INFO :: Iteration=951, Time=2.652175e+01, dt=2.059689e-02
# 2025-02-19 11:57:36,829 __main__ 0/1 INFO :: Iteration=961, Time=2.672772e+01, dt=2.059689e-02
# 2025-02-19 11:57:37,180 __main__ 0/1 INFO :: Iteration=971, Time=2.692332e+01, dt=1.955940e-02
# 2025-02-19 11:57:37,389 __main__ 0/1 INFO :: Iteration=981, Time=2.711891e+01, dt=1.955940e-02
# 2025-02-19 11:57:37,610 __main__ 0/1 INFO :: Iteration=991, Time=2.731450e+01, dt=1.955940e-02
# 2025-02-19 11:57:37,943 __main__ 0/1 INFO :: Iteration=1001, Time=2.752074e+01, dt=2.062332e-02
# 2025-02-19 11:57:38,263 __main__ 0/1 INFO :: Iteration=1011, Time=2.773791e+01, dt=2.171682e-02
# 2025-02-19 11:57:38,581 __main__ 0/1 INFO :: Iteration=1021, Time=2.797171e+01, dt=2.337990e-02
# 2025-02-19 11:57:38,886 __main__ 0/1 INFO :: Iteration=1031, Time=2.823095e+01, dt=2.592427e-02
# 2025-02-19 11:57:39,204 __main__ 0/1 INFO :: Iteration=1041, Time=2.851022e+01, dt=2.792751e-02
# 2025-02-19 11:57:39,423 __main__ 0/1 INFO :: Iteration=1051, Time=2.878950e+01, dt=2.792751e-02
# 2025-02-19 11:57:39,636 __main__ 0/1 INFO :: Iteration=1061, Time=2.906877e+01, dt=2.792751e-02
# 2025-02-19 11:57:39,844 __main__ 0/1 INFO :: Iteration=1071, Time=2.934805e+01, dt=2.792751e-02
# 2025-02-19 11:57:40,050 __main__ 0/1 INFO :: Iteration=1081, Time=2.962732e+01, dt=2.792751e-02
# 2025-02-19 11:57:40,255 __main__ 0/1 INFO :: Iteration=1091, Time=2.990660e+01, dt=2.792751e-02
# 2025-02-19 11:57:40,590 __main__ 0/1 INFO :: Iteration=1101, Time=3.020021e+01, dt=2.936081e-02
# 2025-02-19 11:57:40,805 __main__ 0/1 INFO :: Iteration=1111, Time=3.049381e+01, dt=2.936081e-02
# 2025-02-19 11:57:41,136 __main__ 0/1 INFO :: Iteration=1121, Time=3.081166e+01, dt=3.178473e-02
# 2025-02-19 11:57:41,452 __main__ 0/1 INFO :: Iteration=1131, Time=3.114850e+01, dt=3.368354e-02
# 2025-02-19 11:57:41,764 __main__ 0/1 INFO :: Iteration=1141, Time=3.150641e+01, dt=3.579125e-02
# 2025-02-19 11:57:42,082 __main__ 0/1 INFO :: Iteration=1151, Time=3.181385e+01, dt=3.074384e-02
# 2025-02-19 11:57:42,391 __main__ 0/1 INFO :: Iteration=1161, Time=3.209285e+01, dt=2.790033e-02
# 2025-02-19 11:57:42,700 __main__ 0/1 INFO :: Iteration=1171, Time=3.235455e+01, dt=2.616951e-02
# 2025-02-19 11:57:42,902 __main__ 0/1 INFO :: Iteration=1181, Time=3.261624e+01, dt=2.616951e-02
# 2025-02-19 11:57:43,216 __main__ 0/1 INFO :: Iteration=1191, Time=3.286109e+01, dt=2.448467e-02
# 2025-02-19 11:57:43,425 __main__ 0/1 INFO :: Iteration=1201, Time=3.310593e+01, dt=2.448467e-02
# 2025-02-19 11:57:43,631 __main__ 0/1 INFO :: Iteration=1211, Time=3.335078e+01, dt=2.448467e-02
# 2025-02-19 11:57:43,837 __main__ 0/1 INFO :: Iteration=1221, Time=3.359563e+01, dt=2.448467e-02
# 2025-02-19 11:57:44,147 __main__ 0/1 INFO :: Iteration=1231, Time=3.385801e+01, dt=2.623822e-02
# 2025-02-19 11:57:44,361 __main__ 0/1 INFO :: Iteration=1241, Time=3.412039e+01, dt=2.623822e-02
# 2025-02-19 11:57:44,674 __main__ 0/1 INFO :: Iteration=1251, Time=3.440439e+01, dt=2.840000e-02
# 2025-02-19 11:57:44,878 __main__ 0/1 INFO :: Iteration=1261, Time=3.468839e+01, dt=2.840000e-02
# 2025-02-19 11:57:45,093 __main__ 0/1 INFO :: Iteration=1271, Time=3.497239e+01, dt=2.840000e-02
# 2025-02-19 11:57:45,404 __main__ 0/1 INFO :: Iteration=1281, Time=3.527336e+01, dt=3.009628e-02
# 2025-02-19 11:57:45,622 __main__ 0/1 INFO :: Iteration=1291, Time=3.557432e+01, dt=3.009628e-02
# 2025-02-19 11:57:45,935 __main__ 0/1 INFO :: Iteration=1301, Time=3.589728e+01, dt=3.229641e-02
# 2025-02-19 11:57:46,243 __main__ 0/1 INFO :: Iteration=1311, Time=3.623720e+01, dt=3.399179e-02
# 2025-02-19 11:57:46,564 __main__ 0/1 INFO :: Iteration=1321, Time=3.659952e+01, dt=3.623150e-02
# 2025-02-19 11:57:46,873 __main__ 0/1 INFO :: Iteration=1331, Time=3.687773e+01, dt=2.782164e-02
# 2025-02-19 11:57:47,184 __main__ 0/1 INFO :: Iteration=1341, Time=3.711017e+01, dt=2.324415e-02
# 2025-02-19 11:57:47,497 __main__ 0/1 INFO :: Iteration=1351, Time=3.731898e+01, dt=2.088045e-02
# 2025-02-19 11:57:47,793 __main__ 0/1 INFO :: Iteration=1361, Time=3.751377e+01, dt=1.947954e-02
# 2025-02-19 11:57:48,002 __main__ 0/1 INFO :: Iteration=1371, Time=3.770857e+01, dt=1.947954e-02
# 2025-02-19 11:57:48,308 __main__ 0/1 INFO :: Iteration=1381, Time=3.788987e+01, dt=1.812969e-02
# 2025-02-19 11:57:48,516 __main__ 0/1 INFO :: Iteration=1391, Time=3.807116e+01, dt=1.812969e-02
# 2025-02-19 11:57:48,712 __main__ 0/1 INFO :: Iteration=1401, Time=3.825246e+01, dt=1.812969e-02
# 2025-02-19 11:57:48,918 __main__ 0/1 INFO :: Iteration=1411, Time=3.843376e+01, dt=1.812969e-02
# 2025-02-19 11:57:49,224 __main__ 0/1 INFO :: Iteration=1421, Time=3.862434e+01, dt=1.905800e-02
# 2025-02-19 11:57:49,535 __main__ 0/1 INFO :: Iteration=1431, Time=3.882571e+01, dt=2.013714e-02
# 2025-02-19 11:57:49,843 __main__ 0/1 INFO :: Iteration=1441, Time=3.904400e+01, dt=2.182907e-02
# 2025-02-19 11:57:50,153 __main__ 0/1 INFO :: Iteration=1451, Time=3.928961e+01, dt=2.456094e-02
# 2025-02-19 11:57:50,466 __main__ 0/1 INFO :: Iteration=1461, Time=3.957162e+01, dt=2.820101e-02
# 2025-02-19 11:57:50,669 __main__ 0/1 INFO :: Iteration=1471, Time=3.985363e+01, dt=2.820101e-02
# 2025-02-19 11:57:50,878 __main__ 0/1 INFO :: Iteration=1481, Time=4.013564e+01, dt=2.820101e-02
# 2025-02-19 11:57:51,084 __main__ 0/1 INFO :: Iteration=1491, Time=4.041765e+01, dt=2.820101e-02
# 2025-02-19 11:57:51,394 __main__ 0/1 INFO :: Iteration=1501, Time=4.072100e+01, dt=3.033534e-02
# 2025-02-19 11:57:51,600 __main__ 0/1 INFO :: Iteration=1511, Time=4.102435e+01, dt=3.033534e-02
# 2025-02-19 11:57:51,917 __main__ 0/1 INFO :: Iteration=1521, Time=4.135550e+01, dt=3.311409e-02
# 2025-02-19 11:57:52,217 __main__ 0/1 INFO :: Iteration=1531, Time=4.164634e+01, dt=2.908459e-02
# 2025-02-19 11:57:52,523 __main__ 0/1 INFO :: Iteration=1541, Time=4.189125e+01, dt=2.449039e-02
# 2025-02-19 11:57:52,824 __main__ 0/1 INFO :: Iteration=1551, Time=4.211277e+01, dt=2.215296e-02
# 2025-02-19 11:57:53,126 __main__ 0/1 INFO :: Iteration=1561, Time=4.232144e+01, dt=2.086630e-02
# 2025-02-19 11:57:53,331 __main__ 0/1 INFO :: Iteration=1571, Time=4.253010e+01, dt=2.086630e-02
# 2025-02-19 11:57:53,524 __main__ 0/1 INFO :: Iteration=1581, Time=4.273876e+01, dt=2.086630e-02
# 2025-02-19 11:57:53,724 __main__ 0/1 INFO :: Iteration=1591, Time=4.294743e+01, dt=2.086630e-02
# 2025-02-19 11:57:53,930 __main__ 0/1 INFO :: Iteration=1601, Time=4.315609e+01, dt=2.086630e-02
# 2025-02-19 11:57:54,134 __main__ 0/1 INFO :: Iteration=1611, Time=4.336475e+01, dt=2.086630e-02
# 2025-02-19 11:57:54,435 __main__ 0/1 INFO :: Iteration=1621, Time=4.358646e+01, dt=2.217110e-02
# 2025-02-19 11:57:54,739 __main__ 0/1 INFO :: Iteration=1631, Time=4.382529e+01, dt=2.388291e-02
# 2025-02-19 11:57:55,044 __main__ 0/1 INFO :: Iteration=1641, Time=4.409014e+01, dt=2.648514e-02
# 2025-02-19 11:57:55,248 __main__ 0/1 INFO :: Iteration=1651, Time=4.435500e+01, dt=2.648514e-02
# 2025-02-19 11:57:55,451 __main__ 0/1 INFO :: Iteration=1661, Time=4.461985e+01, dt=2.648514e-02
# 2025-02-19 11:57:55,655 __main__ 0/1 INFO :: Iteration=1671, Time=4.488470e+01, dt=2.648514e-02
# 2025-02-19 11:57:55,859 __main__ 0/1 INFO :: Iteration=1681, Time=4.514955e+01, dt=2.648514e-02
# 2025-02-19 11:57:56,070 __main__ 0/1 INFO :: Iteration=1691, Time=4.541440e+01, dt=2.648514e-02
# 2025-02-19 11:57:56,273 __main__ 0/1 INFO :: Iteration=1701, Time=4.567925e+01, dt=2.648514e-02
# 2025-02-19 11:57:56,586 __main__ 0/1 INFO :: Iteration=1711, Time=4.596313e+01, dt=2.838767e-02
# 2025-02-19 11:57:56,789 __main__ 0/1 INFO :: Iteration=1721, Time=4.624701e+01, dt=2.838767e-02
# 2025-02-19 11:57:57,102 __main__ 0/1 INFO :: Iteration=1731, Time=4.655420e+01, dt=3.071896e-02
# 2025-02-19 11:57:57,405 __main__ 0/1 INFO :: Iteration=1741, Time=4.687959e+01, dt=3.253952e-02
# 2025-02-19 11:57:57,715 __main__ 0/1 INFO :: Iteration=1751, Time=4.722883e+01, dt=3.492430e-02
# 2025-02-19 11:57:58,050 __main__ 0/1 INFO :: Iteration=1761, Time=4.753116e+01, dt=3.023298e-02
# 2025-02-19 11:57:58,346 __main__ 0/1 INFO :: Iteration=1771, Time=4.780171e+01, dt=2.705468e-02
# 2025-02-19 11:57:58,647 __main__ 0/1 INFO :: Iteration=1781, Time=4.805326e+01, dt=2.515461e-02
# 2025-02-19 11:57:58,843 __main__ 0/1 INFO :: Iteration=1791, Time=4.830480e+01, dt=2.515461e-02
# 2025-02-19 11:57:59,143 __main__ 0/1 INFO :: Iteration=1801, Time=4.853745e+01, dt=2.326505e-02
# 2025-02-19 11:57:59,332 __main__ 0/1 INFO :: Iteration=1811, Time=4.877010e+01, dt=2.326505e-02
# 2025-02-19 11:57:59,528 __main__ 0/1 INFO :: Iteration=1821, Time=4.900275e+01, dt=2.326505e-02
# 2025-02-19 11:57:59,724 __main__ 0/1 INFO :: Iteration=1831, Time=4.923540e+01, dt=2.326505e-02
# 2025-02-19 11:57:59,921 __main__ 0/1 INFO :: Iteration=1841, Time=4.946806e+01, dt=2.326505e-02
# 2025-02-19 11:58:00,222 __main__ 0/1 INFO :: Iteration=1851, Time=4.972114e+01, dt=2.530858e-02
# 2025-02-19 11:58:00,431 __main__ 0/1 INFO :: Iteration=1861, Time=4.997423e+01, dt=2.530858e-02
# 2025-02-19 11:58:00,649 __main__ 0/1 INFO :: Iteration=1871, Time=5.022731e+01, dt=2.530858e-02
# 2025-02-19 11:58:00,863 __main__ 0/1 INFO :: Iteration=1881, Time=5.048040e+01, dt=2.530858e-02
# 2025-02-19 11:58:01,184 __main__ 0/1 INFO :: Iteration=1891, Time=5.074936e+01, dt=2.689616e-02
# 2025-02-19 11:58:01,399 __main__ 0/1 INFO :: Iteration=1901, Time=5.101832e+01, dt=2.689616e-02
# 2025-02-19 11:58:01,624 __main__ 0/1 INFO :: Iteration=1911, Time=5.128728e+01, dt=2.689616e-02
# 2025-02-19 11:58:01,945 __main__ 0/1 INFO :: Iteration=1921, Time=5.157763e+01, dt=2.903468e-02
# 2025-02-19 11:58:02,156 __main__ 0/1 INFO :: Iteration=1931, Time=5.186798e+01, dt=2.903468e-02
# 2025-02-19 11:58:02,475 __main__ 0/1 INFO :: Iteration=1941, Time=5.218808e+01, dt=3.201016e-02
# 2025-02-19 11:58:02,687 __main__ 0/1 INFO :: Iteration=1951, Time=5.250818e+01, dt=3.201016e-02
# 2025-02-19 11:58:03,004 __main__ 0/1 INFO :: Iteration=1961, Time=5.275623e+01, dt=2.480544e-02
# 2025-02-19 11:58:03,329 __main__ 0/1 INFO :: Iteration=1971, Time=5.297408e+01, dt=2.178409e-02
# 2025-02-19 11:58:03,656 __main__ 0/1 INFO :: Iteration=1981, Time=5.317485e+01, dt=2.007752e-02
# 2025-02-19 11:58:03,979 __main__ 0/1 INFO :: Iteration=1991, Time=5.336525e+01, dt=1.903979e-02
# 2025-02-19 11:58:04,203 __main__ 0/1 INFO :: Iteration=2001, Time=5.355565e+01, dt=1.903979e-02
# 2025-02-19 11:58:04,409 __main__ 0/1 INFO :: Iteration=2011, Time=5.374604e+01, dt=1.903979e-02
# 2025-02-19 11:58:04,627 __main__ 0/1 INFO :: Iteration=2021, Time=5.393644e+01, dt=1.903979e-02
# 2025-02-19 11:58:04,845 __main__ 0/1 INFO :: Iteration=2031, Time=5.412684e+01, dt=1.903979e-02
# 2025-02-19 11:58:05,062 __main__ 0/1 INFO :: Iteration=2041, Time=5.431724e+01, dt=1.903979e-02
# 2025-02-19 11:58:05,271 __main__ 0/1 INFO :: Iteration=2051, Time=5.450764e+01, dt=1.903979e-02
# 2025-02-19 11:58:05,597 __main__ 0/1 INFO :: Iteration=2061, Time=5.472091e+01, dt=2.132763e-02
# 2025-02-19 11:58:05,923 __main__ 0/1 INFO :: Iteration=2071, Time=5.495692e+01, dt=2.360079e-02
# 2025-02-19 11:58:06,251 __main__ 0/1 INFO :: Iteration=2081, Time=5.521412e+01, dt=2.572016e-02
# 2025-02-19 11:58:06,472 __main__ 0/1 INFO :: Iteration=2091, Time=5.547132e+01, dt=2.572016e-02
# 2025-02-19 11:58:06,692 __main__ 0/1 INFO :: Iteration=2101, Time=5.572852e+01, dt=2.572016e-02
# 2025-02-19 11:58:06,911 __main__ 0/1 INFO :: Iteration=2111, Time=5.598573e+01, dt=2.572016e-02
# 2025-02-19 11:58:07,135 __main__ 0/1 INFO :: Iteration=2121, Time=5.624293e+01, dt=2.572016e-02
# 2025-02-19 11:58:07,355 __main__ 0/1 INFO :: Iteration=2131, Time=5.650013e+01, dt=2.572016e-02
# 2025-02-19 11:58:07,693 __main__ 0/1 INFO :: Iteration=2141, Time=5.677861e+01, dt=2.784812e-02
# 2025-02-19 11:58:07,914 __main__ 0/1 INFO :: Iteration=2151, Time=5.705709e+01, dt=2.784812e-02
# 2025-02-19 11:58:08,242 __main__ 0/1 INFO :: Iteration=2161, Time=5.736407e+01, dt=3.069807e-02
# 2025-02-19 11:58:08,564 __main__ 0/1 INFO :: Iteration=2171, Time=5.763214e+01, dt=2.680626e-02
# 2025-02-19 11:58:08,890 __main__ 0/1 INFO :: Iteration=2181, Time=5.786924e+01, dt=2.371061e-02
# 2025-02-19 11:58:09,208 __main__ 0/1 INFO :: Iteration=2191, Time=5.808984e+01, dt=2.205976e-02
# 2025-02-19 11:58:09,433 __main__ 0/1 INFO :: Iteration=2201, Time=5.831044e+01, dt=2.205976e-02
# 2025-02-19 11:58:09,743 __main__ 0/1 INFO :: Iteration=2211, Time=5.851763e+01, dt=2.071964e-02
# 2025-02-19 11:58:09,962 __main__ 0/1 INFO :: Iteration=2221, Time=5.872483e+01, dt=2.071964e-02
# 2025-02-19 11:58:10,172 __main__ 0/1 INFO :: Iteration=2231, Time=5.893203e+01, dt=2.071964e-02
# 2025-02-19 11:58:10,383 __main__ 0/1 INFO :: Iteration=2241, Time=5.913922e+01, dt=2.071964e-02
# 2025-02-19 11:58:10,699 __main__ 0/1 INFO :: Iteration=2251, Time=5.936472e+01, dt=2.255009e-02
# 2025-02-19 11:58:11,019 __main__ 0/1 INFO :: Iteration=2261, Time=5.960560e+01, dt=2.408781e-02
# 2025-02-19 11:58:11,332 __main__ 0/1 INFO :: Iteration=2271, Time=5.986733e+01, dt=2.617340e-02
# 2025-02-19 11:58:11,540 __main__ 0/1 INFO :: Iteration=2281, Time=6.012907e+01, dt=2.617340e-02
# 2025-02-19 11:58:11,746 __main__ 0/1 INFO :: Iteration=2291, Time=6.039080e+01, dt=2.617340e-02
# 2025-02-19 11:58:11,963 __main__ 0/1 INFO :: Iteration=2301, Time=6.065254e+01, dt=2.617340e-02
# 2025-02-19 11:58:12,169 __main__ 0/1 INFO :: Iteration=2311, Time=6.091427e+01, dt=2.617340e-02
# 2025-02-19 11:58:12,380 __main__ 0/1 INFO :: Iteration=2321, Time=6.117600e+01, dt=2.617340e-02
# 2025-02-19 11:58:12,593 __main__ 0/1 INFO :: Iteration=2331, Time=6.143774e+01, dt=2.617340e-02
# 2025-02-19 11:58:12,803 __main__ 0/1 INFO :: Iteration=2341, Time=6.169947e+01, dt=2.617340e-02
# 2025-02-19 11:58:13,007 __main__ 0/1 INFO :: Iteration=2351, Time=6.196121e+01, dt=2.617340e-02
# 2025-02-19 11:58:13,306 __main__ 0/1 INFO :: Iteration=2361, Time=6.224152e+01, dt=2.803132e-02
# 2025-02-19 11:58:13,617 __main__ 0/1 INFO :: Iteration=2371, Time=6.253612e+01, dt=2.946011e-02
# 2025-02-19 11:58:13,943 __main__ 0/1 INFO :: Iteration=2381, Time=6.284675e+01, dt=3.106281e-02
# 2025-02-19 11:58:14,269 __main__ 0/1 INFO :: Iteration=2391, Time=6.317868e+01, dt=3.319292e-02
# 2025-02-19 11:58:14,596 __main__ 0/1 INFO :: Iteration=2401, Time=6.346419e+01, dt=2.855130e-02
# 2025-02-19 11:58:14,917 __main__ 0/1 INFO :: Iteration=2411, Time=6.372240e+01, dt=2.582099e-02
# 2025-02-19 11:58:15,242 __main__ 0/1 INFO :: Iteration=2421, Time=6.396417e+01, dt=2.417685e-02
# 2025-02-19 11:58:15,458 __main__ 0/1 INFO :: Iteration=2431, Time=6.420594e+01, dt=2.417685e-02
# 2025-02-19 11:58:15,763 __main__ 0/1 INFO :: Iteration=2441, Time=6.443218e+01, dt=2.262372e-02
# 2025-02-19 11:58:15,963 __main__ 0/1 INFO :: Iteration=2451, Time=6.465841e+01, dt=2.262372e-02
# 2025-02-19 11:58:16,161 __main__ 0/1 INFO :: Iteration=2461, Time=6.488465e+01, dt=2.262372e-02
# 2025-02-19 11:58:16,362 __main__ 0/1 INFO :: Iteration=2471, Time=6.511089e+01, dt=2.262372e-02
# 2025-02-19 11:58:16,664 __main__ 0/1 INFO :: Iteration=2481, Time=6.535258e+01, dt=2.416937e-02
# 2025-02-19 11:58:16,864 __main__ 0/1 INFO :: Iteration=2491, Time=6.559427e+01, dt=2.416937e-02
# 2025-02-19 11:58:17,065 __main__ 0/1 INFO :: Iteration=2501, Time=6.583597e+01, dt=2.416937e-02
# 2025-02-19 11:58:17,265 __main__ 0/1 INFO :: Iteration=2511, Time=6.607766e+01, dt=2.416937e-02
# 2025-02-19 11:58:17,464 __main__ 0/1 INFO :: Iteration=2521, Time=6.631936e+01, dt=2.416937e-02
# 2025-02-19 11:58:17,766 __main__ 0/1 INFO :: Iteration=2531, Time=6.657527e+01, dt=2.559155e-02
# 2025-02-19 11:58:17,968 __main__ 0/1 INFO :: Iteration=2541, Time=6.683119e+01, dt=2.559155e-02
# 2025-02-19 11:58:18,268 __main__ 0/1 INFO :: Iteration=2551, Time=6.710240e+01, dt=2.712152e-02
# 2025-02-19 11:58:18,472 __main__ 0/1 INFO :: Iteration=2561, Time=6.737362e+01, dt=2.712152e-02
# 2025-02-19 11:58:18,778 __main__ 0/1 INFO :: Iteration=2571, Time=6.767491e+01, dt=3.012922e-02
# 2025-02-19 11:58:19,081 __main__ 0/1 INFO :: Iteration=2581, Time=6.799801e+01, dt=3.231006e-02
# 2025-02-19 11:58:19,390 __main__ 0/1 INFO :: Iteration=2591, Time=6.828631e+01, dt=2.882992e-02
# 2025-02-19 11:58:19,689 __main__ 0/1 INFO :: Iteration=2601, Time=6.852330e+01, dt=2.369959e-02
# 2025-02-19 11:58:19,991 __main__ 0/1 INFO :: Iteration=2611, Time=6.873423e+01, dt=2.109257e-02
# 2025-02-19 11:58:20,299 __main__ 0/1 INFO :: Iteration=2621, Time=6.892992e+01, dt=1.956870e-02
# 2025-02-19 11:58:20,509 __main__ 0/1 INFO :: Iteration=2631, Time=6.912560e+01, dt=1.956870e-02
# 2025-02-19 11:58:20,887 __main__ 0/1 INFO :: Iteration=2641, Time=6.930624e+01, dt=1.806394e-02
# 2025-02-19 11:58:21,084 __main__ 0/1 INFO :: Iteration=2651, Time=6.948688e+01, dt=1.806394e-02
# 2025-02-19 11:58:21,291 __main__ 0/1 INFO :: Iteration=2661, Time=6.966752e+01, dt=1.806394e-02
# 2025-02-19 11:58:21,502 __main__ 0/1 INFO :: Iteration=2671, Time=6.984816e+01, dt=1.806394e-02
# 2025-02-19 11:58:21,708 __main__ 0/1 INFO :: Iteration=2681, Time=7.002880e+01, dt=1.806394e-02
# 2025-02-19 11:58:22,009 __main__ 0/1 INFO :: Iteration=2691, Time=7.022358e+01, dt=1.947827e-02
# 2025-02-19 11:58:22,326 __main__ 0/1 INFO :: Iteration=2701, Time=7.043184e+01, dt=2.082529e-02
# 2025-02-19 11:58:22,636 __main__ 0/1 INFO :: Iteration=2711, Time=7.066113e+01, dt=2.292937e-02
# 2025-02-19 11:58:22,840 __main__ 0/1 INFO :: Iteration=2721, Time=7.089042e+01, dt=2.292937e-02
# 2025-02-19 11:58:23,049 __main__ 0/1 INFO :: Iteration=2731, Time=7.111972e+01, dt=2.292937e-02
# 2025-02-19 11:58:23,259 __main__ 0/1 INFO :: Iteration=2741, Time=7.134901e+01, dt=2.292937e-02
# 2025-02-19 11:58:23,565 __main__ 0/1 INFO :: Iteration=2751, Time=7.159312e+01, dt=2.441073e-02
# 2025-02-19 11:58:23,816 __main__ 0/1 INFO :: Iteration=2761, Time=7.183723e+01, dt=2.441073e-02
# 2025-02-19 11:58:24,129 __main__ 0/1 INFO :: Iteration=2771, Time=7.209675e+01, dt=2.595240e-02
# 2025-02-19 11:58:24,342 __main__ 0/1 INFO :: Iteration=2781, Time=7.235627e+01, dt=2.595240e-02
# 2025-02-19 11:58:24,650 __main__ 0/1 INFO :: Iteration=2791, Time=7.264267e+01, dt=2.863972e-02
# 2025-02-19 11:58:24,982 __main__ 0/1 INFO :: Iteration=2801, Time=7.295193e+01, dt=3.092612e-02
# 2025-02-19 11:58:25,329 __main__ 0/1 INFO :: Iteration=2811, Time=7.323336e+01, dt=2.814296e-02
# 2025-02-19 11:58:25,689 __main__ 0/1 INFO :: Iteration=2821, Time=7.347280e+01, dt=2.394340e-02
# 2025-02-19 11:58:26,023 __main__ 0/1 INFO :: Iteration=2831, Time=7.369039e+01, dt=2.175888e-02
# 2025-02-19 11:58:26,350 __main__ 0/1 INFO :: Iteration=2841, Time=7.389540e+01, dt=2.050126e-02
# 2025-02-19 11:58:26,561 __main__ 0/1 INFO :: Iteration=2851, Time=7.410041e+01, dt=2.050126e-02
# 2025-02-19 11:58:26,866 __main__ 0/1 INFO :: Iteration=2861, Time=7.429442e+01, dt=1.940087e-02
# 2025-02-19 11:58:27,067 __main__ 0/1 INFO :: Iteration=2871, Time=7.448843e+01, dt=1.940087e-02
# 2025-02-19 11:58:27,278 __main__ 0/1 INFO :: Iteration=2881, Time=7.468244e+01, dt=1.940087e-02
# 2025-02-19 11:58:27,484 __main__ 0/1 INFO :: Iteration=2891, Time=7.487644e+01, dt=1.940087e-02
# 2025-02-19 11:58:27,698 solvers 0/1 INFO :: Simulation stop time reached.
# 2025-02-19 11:58:27,699 solvers 0/1 INFO :: Final iteration: 2897
# 2025-02-19 11:58:27,699 solvers 0/1 INFO :: Final sim time: 75.00075185191804
# 2025-02-19 11:58:27,699 solvers 0/1 INFO :: Setup time (init - iter 0): 3.063 sec
# 2025-02-19 11:58:27,700 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.4453 sec
# 2025-02-19 11:58:27,700 solvers 0/1 INFO :: Run time (iter 10-end): 76.18 sec
# 2025-02-19 11:58:27,700 solvers 0/1 INFO :: CPU time (iter 10-end): 0.02116 cpu-hr
# 2025-02-19 11:58:27,700 solvers 0/1 INFO :: Speed: 6.088e+06 mode-stages/cpu-sec

# %% [markdown]
# # Plot the solution

# %%
import h5py
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import cmocean.cm as cmo
import dedalus.public as d3
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import os
from PIL import Image
from mpl_toolkits.axes_grid1 import make_axes_locatable
import xarray as xr

# %%
simdata = './snapshots/snapshots_s1.h5'

# %%
# See what is in the data files
with h5py.File(simdata, mode='r') as file:
    a_group_key = list(file.keys())
    print(a_group_key)
    
    print(file['scales'])
    print(list(file['scales']))
    print(file['tasks'])
    print(list(file['tasks']))
# Out:
# ['scales', 'tasks']
# <HDF5 group "/scales" (9 members)>
# ['constant', 'iteration', 'sim_time', 'timestep', 'wall_time', 'world_time', 'write_number', 'x_hash_4ed81b13f0aa908bb9caefe50f9a8b6a31597485', 'z_hash_65f3ebdbcb657c9267ce1ace1566dac45ab827ca']
# <HDF5 group "/tasks" (4 members)>
# ['buoyancy', 'pressure', 'tracer', 'uvec']

# %%
# Actually read in data files
with h5py.File(simdata, mode='r') as file:
    
    b_data = np.squeeze(np.array(file['tasks']['buoyancy']))
    print('b shape: ' + str(b_data.shape))
    u_data = np.squeeze(np.array(file['tasks']['uvec']))
    print('u_data: ' + str(u_data.shape))
    p_data = np.squeeze(np.array(file['tasks']['pressure']))
    print('p_data: ' + str(p_data.shape))
    c_data = np.squeeze(np.array(file['tasks']['tracer']))
    print('c_data: ' + str(p_data.shape))
    #vort_data = np.squeeze(np.array(file['tasks']['vorticity']))
    #div_data = np.squeeze(np.array(file['tasks']['divergence']))
    
    sim_time_ary = np.array(file['scales']['sim_time'])
    print(sim_time_ary.shape)
    
    x = np.array(file['scales'][list(file['scales'])[-2]])
    z = np.array(file['scales'][list(file['scales'])[-1]])
# Out:
# b shape: (300, 256, 64)
# u_data: (300, 2, 256, 64)
# p_data: (300, 256, 64)
# c_data: (300, 256, 64)
# (300,)

# %%
# Put data in xarray, as it is nice way to keep things organized
ds_sim = xr.Dataset()

ds_sim['b'] = xr.DataArray(b_data, coords = {'time':sim_time_ary, 'x':x, 'z':z})
ds_sim['p'] = xr.DataArray(p_data, coords = {'time':sim_time_ary, 'x':x, 'z':z})
ds_sim['u'] = xr.DataArray(u_data[:,0,:,:].squeeze(), coords = {'time':sim_time_ary, 'x':x, 'z':z})
ds_sim['w'] = xr.DataArray(u_data[:,0,:,:].squeeze(), coords = {'time':sim_time_ary, 'x':x, 'z':z})
ds_sim['c'] = xr.DataArray(c_data, coords = {'time':sim_time_ary, 'x':x, 'z':z})

# %%
ds_sim
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 300, x: 256, z: 64)
# Coordinates:
#   * time     (time) float64 0.0 0.25 0.5 0.75 1.0 ... 74.02 74.26 74.51 74.76
#   * x        (x) float64 -4.0 -3.969 -3.938 -3.906 ... 3.875 3.906 3.938 3.969
#   * z        (z) float64 -1.0 -0.9688 -0.9375 -0.9062 ... 0.9062 0.9375 0.9688
# Data variables:
#     b        (time, x, z) float64 0.0 0.0 0.0 0.0 ... 0.352 0.4063 0.4487 0.4757
#     p        (time, x, z) float64 0.0 0.0 0.0 0.0 ... -0.02567 -0.0177 -0.009032
#     u        (time, x, z) float64 0.0 0.0 0.0 0.0 ... 0.03216 0.02287 0.01189
#     w        (time, x, z) float64 0.0 0.0 0.0 0.0 ... 0.03216 0.02287 0.01189
#     c        (time, x, z) float64 1.004 1.0 0.9861 0.9628 ... 0.212 0.212 0.212

# %%
plt.figure(figsize=(8, 10))
plt.subplot(4,1,1)
ds_sim.u.isel(time=-1).plot(x='x')

plt.subplot(4,1,2)
ds_sim.w.isel(time=-1).plot(x='x')

plt.subplot(4,1,3)
ds_sim.b.isel(time=-1).plot(x='x')

plt.subplot(4,1,4)
ds_sim.p.isel(time=-1).plot(x='x')

plt.tight_layout()

# %%
plt.figure(figsize=(3, 8))
#plt.pcolormesh(x, y, b_data[20, :,:].T)
ds_sim.b.sel(x=-0.5, method='nearest').plot(x='z')

# %%
ds_sim.c.isel(time=11).plot(x='x')

# %% [markdown]
# Make a movie of a certain field

# %%
def create_animation(fun, idx, filename='my-animation.gif', dpi=200, FPS=18, loop=0):
    '''
    See https://pythonprogramming.altervista.org/png-to-gif/
    fun(i) - a function creating one snapshot, has only one input:
        - number of frame i
    idx - range of frames, i in idx
    FPS - frames per second
    filename - animation name
    dpi - set 300 or so to increase quality
    loop - number of repeats of the gif
    '''
    frames = []
    for i in idx:
        fun(i)
        plt.savefig('.frame.png', dpi=dpi, bbox_inches='tight')
        plt.close()
        frames.append(Image.open('.frame.png').convert('RGB'))
        print(f'Frame {i} is created', end='\r')
    os.system('rm .frame.png')
    # How long to persist one frame in milliseconds to have a desired FPS
    duration = 1000 / FPS
    print(f'Animation at FPS={FPS} will last for {len(idx)/FPS} seconds')
    frames[0].save(
        filename, format='GIF',
        append_images=frames[1:],
        save_all=True,
        duration=duration,
        loop=loop)

# %%
# This function needs to be modified as needed if you want to make other movies
def plot_fun(time_idx): 
    vmin=-1 
    fig = plt.figure(figsize=(6, 2))
    
    ds_sim.b.isel(time=time_idx).plot(x='x', vmin=vmin)
    plt.gca().set_aspect('equal')
    
    plt.title(f"{sim_time_ary[time_idx]:.2f} s")

    plt.tight_layout()

# %%
plot_fun(-1)

# %%
fname = 'GW.gif'
create_animation(plot_fun, range(0, len(sim_time_ary), 1), filename=fname)
# Out:
# Frame 168 is created
